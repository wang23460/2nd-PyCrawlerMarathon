# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11647558419","type":"PushEvent","actor":{"id":46246528,"login":"jfournierphoto","display_login":"jfournierphoto","gravatar_id":"","url":"https://api.github.com/users/jfournierphoto","avatar_url":"https://avatars.githubusercontent.com/u/46246528?"},"repo":{"id":164962255,"name":"jfournierphoto/Home-Assistant-Config","url":"https://api.github.com/repos/jfournierphoto/Home-Assistant-Config"},"payload":{"push_id":4702131884,"size":1,"distinct_size":1,"ref":"refs/heads/configuration-setup-changes","head":"5c86bc70fdc6cae165b2f4fc33bf31857effb2fd","before":"20deb058a191d9d335a148d571c159391248c910","commits":[{"sha":"5c86bc70fdc6cae165b2f4fc33bf31857effb2fd","author":{"email":"46246528+jfournierphoto@users.noreply.github.com","name":"Jacques Fournier"},"message":"Rename packages/time.yaml to components/time.yaml","distinct":true,"url":"https://api.github.com/repos/jfournierphoto/Home-Assistant-Config/commits/5c86bc70fdc6cae165b2f4fc33bf31857effb2fd"}]},"public":true,"created_at":"2020-03-01T15:49:08Z"},{"id":"11647558418","type":"CreateEvent","actor":{"id":17003142,"login":"50416028","display_login":"50416028","gravatar_id":"","url":"https://api.github.com/users/50416028","avatar_url":"https://avatars.githubusercontent.com/u/17003142?"},"repo":{"id":244176534,"name":"50416028/scraping","url":"https://api.github.com/repos/50416028/scraping"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-03-01T15:49:08Z"},{"id":"11647558415","type":"PushEvent","actor":{"id":49569721,"login":"GitClock","display_login":"GitClock","gravatar_id":"","url":"https://api.github.com/users/GitClock","avatar_url":"https://avatars.githubusercontent.com/u/49569721?"},"repo":{"id":181066494,"name":"GitClock/GitClock","url":"https://api.github.com/repos/GitClock/GitClock"},"payload":{"push_id":4702131878,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"03db3b6ca4b1bc3a369efe41775d4bcd37b39e32","before":"8dd92ea42817cdf5effe907b6e2f1851e433c06d","commits":[{"sha":"03db3b6ca4b1bc3a369efe41775d4bcd37b39e32","author":{"email":"gitclock@protonmail.com","name":"GitClock"},"message":"update time","distinct":true,"url":"https://api.github.com/repos/GitClock/GitClock/commits/03db3b6ca4b1bc3a369efe41775d4bcd37b39e32"}]},"public":true,"created_at":"2020-03-01T15:49:08Z"},{"id":"11647558413","type":"WatchEvent","actor":{"id":648976,"login":"vortexdev","display_login":"vortexdev","gravatar_id":"","url":"https://api.github.com/users/vortexdev","avatar_url":"https://avatars.githubusercontent.com/u/648976?"},"repo":{"id":242322437,"name":"alifanov/regex-helper","url":"https://api.github.com/repos/alifanov/regex-helper"},"payload":{"action":"started"},"public":true,"created_at":"2020-03-01T15:49:08Z"},{"id":"11647558406","type":"PushEvent","actor":{"id":59492460,"login":"ramdevops007","display_login":"ramdevops007","gravatar_id":"","url":"https://api.github.com/users/ramdevops007","avatar_url":"https://avatars.githubusercontent.com/u/59492460?"},"repo":{"id":236114684,"name":"ramdevops2020/webapp","url":"https://api.github.com/repos/ramdevops2020/webapp"},"payload":{"push_id":4702131871,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"42d2e54e7416fe8b321428adb866f2b33db24fc7","before":"deaa702ae8f9074ee17b4bd7414b425e4a399e33","commits":[{"sha":"42d2e54e7416fe8b321428adb866f2b33db24fc7","author":{"email":"59492460+ramdevops007@users.noreply.github.com","name":"ramdevops007"},"message":"Update pom.xml","distinct":true,"url":"https://api.github.com/repos/ramdevops2020/webapp/commits/42d2e54e7416fe8b321428adb866f2b33db24fc7"}]},"public":true,"created_at":"2020-03-01T15:49:08Z","org":{"id":59630554,"login":"ramdevops2020","gravatar_id":"","url":"https://api.github.com/orgs/ramdevops2020","avatar_url":"https://avatars.githubusercontent.com/u/59630554?"}},{"id":"11647558404","type":"CreateEvent","actor":{"id":58561319,"login":"cjxd-bot-test","display_login":" ...

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11647558419',
#   'type': 'PushEvent',
#   'actor': {'id': 46246528,
#    'login': 'jfournierphoto',
#    'display_login': 'jfournierphoto',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jfournierphoto',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46246528?'},
#   'repo': {'id': 164962255,
#    'name': 'jfournierphoto/Home-Assistant-Config',
#    'url': 'https://api.github.com/repos/jfournierphoto/Home-Assistant-Config'},
#   'payload': {'push_id': 4702131884,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/configuration-setup-changes',
#    'head': '5c86bc70fdc6cae165b2f4fc33bf31857effb2fd',
#    'before': '20deb058a191d9d335a148d571c159391248c910',
#    'commits': [{'sha': '5c86bc70fdc6cae165b2f4fc33bf31857effb2fd',
#      'author': {'email': '46246528+jfournierphoto@users.noreply.github.com',
#       'name': 'Jacques Fournier'},
#      'message': 'Rename packages/time.yaml to components/time.yaml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jfournierphoto/Home-Assistant-Config/commits/5c86bc70fdc6cae165b2f4fc33bf31857effb2fd'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558418',
#   'type': 'CreateEvent',
#   'actor': {'id': 17003142,
#    'login': '50416028',
#    'display_login': '50416028',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/50416028',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17003142?'},
#   'repo': {'id': 244176534,
#    'name': '50416028/scraping',
#    'url': 'https://api.github.com/repos/50416028/scraping'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558415',
#   'type': 'PushEvent',
#   'actor': {'id': 49569721,
#    'login': 'GitClock',
#    'display_login': 'GitClock',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GitClock',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49569721?'},
#   'repo': {'id': 181066494,
#    'name': 'GitClock/GitClock',
#    'url': 'https://api.github.com/repos/GitClock/GitClock'},
#   'payload': {'push_id': 4702131878,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '03db3b6ca4b1bc3a369efe41775d4bcd37b39e32',
#    'before': '8dd92ea42817cdf5effe907b6e2f1851e433c06d',
#    'commits': [{'sha': '03db3b6ca4b1bc3a369efe41775d4bcd37b39e32',
#      'author': {'email': 'gitclock@protonmail.com', 'name': 'GitClock'},
#      'message': 'update time',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GitClock/GitClock/commits/03db3b6ca4b1bc3a369efe41775d4bcd37b39e32'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558413',
#   'type': 'WatchEvent',
#   'actor': {'id': 648976,
#    'login': 'vortexdev',
#    'display_login': 'vortexdev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vortexdev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/648976?'},
#   'repo': {'id': 242322437,
#    'name': 'alifanov/regex-helper',
#    'url': 'https://api.github.com/repos/alifanov/regex-helper'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558406',
#   'type': 'PushEvent',
#   'actor': {'id': 59492460,
#    'login': 'ramdevops007',
#    'display_login': 'ramdevops007',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ramdevops007',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59492460?'},
#   'repo': {'id': 236114684,
#    'name': 'ramdevops2020/webapp',
#    'url': 'https://api.github.com/repos/ramdevops2020/webapp'},
#   'payload': {'push_id': 4702131871,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '42d2e54e7416fe8b321428adb866f2b33db24fc7',
#    'before': 'deaa702ae8f9074ee17b4bd7414b425e4a399e33',
#    'commits': [{'sha': '42d2e54e7416fe8b321428adb866f2b33db24fc7',
#      'author': {'email': '59492460+ramdevops007@users.noreply.github.com',
#       'name': 'ramdevops007'},
#      'message': 'Update pom.xml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ramdevops2020/webapp/commits/42d2e54e7416fe8b321428adb866f2b33db24fc7'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z',
#   'org': {'id': 59630554,
#    'login': 'ramdevops2020',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ramdevops2020',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59630554?'}},
#  {'id': '11647558404',
#   'type': 'CreateEvent',
#   'actor': {'id': 58561319,
#    'login': 'cjxd-bot-test',
#    'display_login': 'cjxd-bot-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cjxd-bot-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58561319?'},
#   'repo': {'id': 244162268,
#    'name': 'cb-kubecd/environment-pr-170-73-boot-gke-dev',
#    'url': 'https://api.github.com/repos/cb-kubecd/environment-pr-170-73-boot-gke-dev'},
#   'payload': {'ref': 'v0.0.8',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z',
#   'org': {'id': 43623793,
#    'login': 'cb-kubecd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cb-kubecd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43623793?'}},
#  {'id': '11647558400',
#   'type': 'PushEvent',
#   'actor': {'id': 57688594,
#    'login': 'PawelPyc154',
#    'display_login': 'PawelPyc154',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PawelPyc154',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57688594?'},
#   'repo': {'id': 223755195,
#    'name': 'PawelPyc154/Project-6',
#    'url': 'https://api.github.com/repos/PawelPyc154/Project-6'},
#   'payload': {'push_id': 4702131866,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': 'f14718a754ac0f3fb9396fce13b11bb7bf1e9050',
#    'before': 'd5de5d5a58ef86836cad33c372405af6cec281f6',
#    'commits': [{'sha': 'f14718a754ac0f3fb9396fce13b11bb7bf1e9050',
#      'author': {'email': 'pawelpyc154@gmail.comnpm', 'name': 'PawelPyc154'},
#      'message': 'Updates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PawelPyc154/Project-6/commits/f14718a754ac0f3fb9396fce13b11bb7bf1e9050'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558398',
#   'type': 'PushEvent',
#   'actor': {'id': 61365425,
#    'login': 'antman999',
#    'display_login': 'antman999',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/antman999',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61365425?'},
#   'repo': {'id': 244069406,
#    'name': 'antman999/programming-univbasics-4-square-array-nyc01-seng-ft-042020',
#    'url': 'https://api.github.com/repos/antman999/programming-univbasics-4-square-array-nyc01-seng-ft-042020'},
#   'payload': {'push_id': 4702131867,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': 'f5c380642320286430cdd8b9d02cf4696d896bb4',
#    'before': 'c5a43914c3c64f48c564761936b167ad2d66a018',
#    'commits': [{'sha': 'f5c380642320286430cdd8b9d02cf4696d896bb4',
#      'author': {'email': 'anthonymendoza9922@gmail.com',
#       'name': 'Anthony mendoza'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/antman999/programming-univbasics-4-square-array-nyc01-seng-ft-042020/commits/f5c380642320286430cdd8b9d02cf4696d896bb4'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558393',
#   'type': 'PushEvent',
#   'actor': {'id': 33757315,
#    'login': 'kl3eo',
#    'display_login': 'kl3eo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kl3eo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33757315?'},
#   'repo': {'id': 243860071,
#    'name': 'kl3eo/coinmarkets_api',
#    'url': 'https://api.github.com/repos/kl3eo/coinmarkets_api'},
#   'payload': {'push_id': 4702131858,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '26816dd9ff3ea8fece8d9d611b813733d6cbfb10',
#    'before': '596f9a7add8c4b32c6a93870650f679509032719',
#    'commits': [{'sha': '26816dd9ff3ea8fece8d9d611b813733d6cbfb10',
#      'author': {'email': 'alex@pgrocks.com', 'name': 'kl3eo'},
#      'message': 'more concise grouping clause in selectors',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kl3eo/coinmarkets_api/commits/26816dd9ff3ea8fece8d9d611b813733d6cbfb10'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558388',
#   'type': 'PushEvent',
#   'actor': {'id': 39525716,
#    'login': 'soulehshaikh99',
#    'display_login': 'soulehshaikh99',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/soulehshaikh99',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39525716?'},
#   'repo': {'id': 241298946,
#    'name': 'soulehshaikh99/netlifytest',
#    'url': 'https://api.github.com/repos/soulehshaikh99/netlifytest'},
#   'payload': {'push_id': 4702131862,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '27ac7a7ad2a809e0b7617fd9bb5c6213d440d114',
#    'before': 'a7819862e9fb2a9539a948adcb08702c257be5ae',
#    'commits': [{'sha': '27ac7a7ad2a809e0b7617fd9bb5c6213d440d114',
#      'author': {'email': 'soulehshaikh99@gmail.com', 'name': 'soulehshaikh99'},
#      'message': 'Initial Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/soulehshaikh99/netlifytest/commits/27ac7a7ad2a809e0b7617fd9bb5c6213d440d114'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558385',
#   'type': 'PushEvent',
#   'actor': {'id': 5968704,
#    'login': 'alainsaas',
#    'display_login': 'alainsaas',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alainsaas',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5968704?'},
#   'repo': {'id': 244112179,
#    'name': 'alainsaas/prompt-wy',
#    'url': 'https://api.github.com/repos/alainsaas/prompt-wy'},
#   'payload': {'push_id': 4702131857,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '837a42a05108734dbff7e454808dde12adff1325',
#    'before': '19996cca8901225cfa68b65e12020b600aafdd76',
#    'commits': [{'sha': '837a42a05108734dbff7e454808dde12adff1325',
#      'author': {'email': 'alainsaas@gmail.com', 'name': 'Alain Saas'},
#      'message': 'example',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alainsaas/prompt-wy/commits/837a42a05108734dbff7e454808dde12adff1325'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558392',
#   'type': 'WatchEvent',
#   'actor': {'id': 9139314,
#    'login': 'sneJ-',
#    'display_login': 'sneJ-',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sneJ-',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9139314?'},
#   'repo': {'id': 7258685,
#    'name': 'cloudius-systems/osv',
#    'url': 'https://api.github.com/repos/cloudius-systems/osv'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z',
#   'org': {'id': 3273374,
#    'login': 'cloudius-systems',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cloudius-systems',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3273374?'}},
#  {'id': '11647558390',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 23270420,
#    'login': 'g-leech',
#    'display_login': 'g-leech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/g-leech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23270420?'},
#   'repo': {'id': 77863671,
#    'name': 'g-leech/argmin-gravitas',
#    'url': 'https://api.github.com/repos/g-leech/argmin-gravitas'},
#   'payload': {'action': 'closed',
#    'number': 530,
#    'pull_request': {'url': 'https://api.github.com/repos/g-leech/argmin-gravitas/pulls/530',
#     'id': 193097426,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MTkzMDk3NDI2',
#     'html_url': 'https://github.com/g-leech/argmin-gravitas/pull/530',
#     'diff_url': 'https://github.com/g-leech/argmin-gravitas/pull/530.diff',
#     'patch_url': 'https://github.com/g-leech/argmin-gravitas/pull/530.patch',
#     'issue_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/issues/530',
#     'number': 530,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Someone loves you!: should-we-abolish-foreign-aid',
#     'user': {'login': 'staticmanapp',
#      'id': 15851864,
#      'node_id': 'MDQ6VXNlcjE1ODUxODY0',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/15851864?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/staticmanapp',
#      'html_url': 'https://github.com/staticmanapp',
#      'followers_url': 'https://api.github.com/users/staticmanapp/followers',
#      'following_url': 'https://api.github.com/users/staticmanapp/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/staticmanapp/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/staticmanapp/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/staticmanapp/subscriptions',
#      'organizations_url': 'https://api.github.com/users/staticmanapp/orgs',
#      'repos_url': 'https://api.github.com/users/staticmanapp/repos',
#      'events_url': 'https://api.github.com/users/staticmanapp/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/staticmanapp/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "Dear human,\n\nHere's a new entry for your approval. :tada:\n\nMerge the pull request to accept it, or close it to send it away.\n\n:heart: Your friend [Staticman](https://staticman.net) :muscle:\n\n---\n| Field     | Content                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
#     'created_at': '2018-06-06T18:13:30Z',
#     'updated_at': '2020-03-01T15:49:07Z',
#     'closed_at': '2020-03-01T15:49:07Z',
#     'merged_at': None,
#     'merge_commit_sha': 'da9089762be4a51787de17721b428bab65a765ad',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/pulls/530/commits',
#     'review_comments_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/pulls/530/comments',
#     'review_comment_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/issues/530/comments',
#     'statuses_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/statuses/0d0caa9f7e59b5a891421456ab535a196fcce851',
#     'head': {'label': 'g-leech:staticman_4f4e51d0-69b5-11e8-923b-09e0420093dc',
#      'ref': 'staticman_4f4e51d0-69b5-11e8-923b-09e0420093dc',
#      'sha': '0d0caa9f7e59b5a891421456ab535a196fcce851',
#      'user': {'login': 'g-leech',
#       'id': 23270420,
#       'node_id': 'MDQ6VXNlcjIzMjcwNDIw',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/23270420?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/g-leech',
#       'html_url': 'https://github.com/g-leech',
#       'followers_url': 'https://api.github.com/users/g-leech/followers',
#       'following_url': 'https://api.github.com/users/g-leech/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/g-leech/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/g-leech/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/g-leech/subscriptions',
#       'organizations_url': 'https://api.github.com/users/g-leech/orgs',
#       'repos_url': 'https://api.github.com/users/g-leech/repos',
#       'events_url': 'https://api.github.com/users/g-leech/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/g-leech/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 77863671,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3Nzg2MzY3MQ==',
#       'name': 'argmin-gravitas',
#       'full_name': 'g-leech/argmin-gravitas',
#       'private': False,
#       'owner': {'login': 'g-leech',
#        'id': 23270420,
#        'node_id': 'MDQ6VXNlcjIzMjcwNDIw',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/23270420?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/g-leech',
#        'html_url': 'https://github.com/g-leech',
#        'followers_url': 'https://api.github.com/users/g-leech/followers',
#        'following_url': 'https://api.github.com/users/g-leech/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/g-leech/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/g-leech/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/g-leech/subscriptions',
#        'organizations_url': 'https://api.github.com/users/g-leech/orgs',
#        'repos_url': 'https://api.github.com/users/g-leech/repos',
#        'events_url': 'https://api.github.com/users/g-leech/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/g-leech/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/g-leech/argmin-gravitas',
#       'description': 'My seriousface site',
#       'fork': False,
#       'url': 'https://api.github.com/repos/g-leech/argmin-gravitas',
#       'forks_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/forks',
#       'keys_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/teams',
#       'hooks_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/hooks',
#       'issue_events_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/events',
#       'assignees_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/tags',
#       'blobs_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/languages',
#       'stargazers_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/stargazers',
#       'contributors_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/contributors',
#       'subscribers_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/subscribers',
#       'subscription_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/subscription',
#       'commits_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/merges',
#       'archive_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/downloads',
#       'issues_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/deployments',
#       'created_at': '2017-01-02T21:42:31Z',
#       'updated_at': '2020-03-01T15:26:08Z',
#       'pushed_at': '2020-03-01T15:49:07Z',
#       'git_url': 'git://github.com/g-leech/argmin-gravitas.git',
#       'ssh_url': 'git@github.com:g-leech/argmin-gravitas.git',
#       'clone_url': 'https://github.com/g-leech/argmin-gravitas.git',
#       'svn_url': 'https://github.com/g-leech/argmin-gravitas',
#       'homepage': 'https://www.gleech.org',
#       'size': 26612,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Jupyter Notebook',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 4,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'g-leech:master',
#      'ref': 'master',
#      'sha': '6c425a3d3e486a7a6388864977cec9d7d3b85580',
#      'user': {'login': 'g-leech',
#       'id': 23270420,
#       'node_id': 'MDQ6VXNlcjIzMjcwNDIw',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/23270420?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/g-leech',
#       'html_url': 'https://github.com/g-leech',
#       'followers_url': 'https://api.github.com/users/g-leech/followers',
#       'following_url': 'https://api.github.com/users/g-leech/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/g-leech/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/g-leech/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/g-leech/subscriptions',
#       'organizations_url': 'https://api.github.com/users/g-leech/orgs',
#       'repos_url': 'https://api.github.com/users/g-leech/repos',
#       'events_url': 'https://api.github.com/users/g-leech/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/g-leech/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 77863671,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3Nzg2MzY3MQ==',
#       'name': 'argmin-gravitas',
#       'full_name': 'g-leech/argmin-gravitas',
#       'private': False,
#       'owner': {'login': 'g-leech',
#        'id': 23270420,
#        'node_id': 'MDQ6VXNlcjIzMjcwNDIw',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/23270420?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/g-leech',
#        'html_url': 'https://github.com/g-leech',
#        'followers_url': 'https://api.github.com/users/g-leech/followers',
#        'following_url': 'https://api.github.com/users/g-leech/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/g-leech/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/g-leech/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/g-leech/subscriptions',
#        'organizations_url': 'https://api.github.com/users/g-leech/orgs',
#        'repos_url': 'https://api.github.com/users/g-leech/repos',
#        'events_url': 'https://api.github.com/users/g-leech/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/g-leech/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/g-leech/argmin-gravitas',
#       'description': 'My seriousface site',
#       'fork': False,
#       'url': 'https://api.github.com/repos/g-leech/argmin-gravitas',
#       'forks_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/forks',
#       'keys_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/teams',
#       'hooks_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/hooks',
#       'issue_events_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/events',
#       'assignees_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/tags',
#       'blobs_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/languages',
#       'stargazers_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/stargazers',
#       'contributors_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/contributors',
#       'subscribers_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/subscribers',
#       'subscription_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/subscription',
#       'commits_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/merges',
#       'archive_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/downloads',
#       'issues_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/g-leech/argmin-gravitas/deployments',
#       'created_at': '2017-01-02T21:42:31Z',
#       'updated_at': '2020-03-01T15:26:08Z',
#       'pushed_at': '2020-03-01T15:49:07Z',
#       'git_url': 'git://github.com/g-leech/argmin-gravitas.git',
#       'ssh_url': 'git@github.com:g-leech/argmin-gravitas.git',
#       'clone_url': 'https://github.com/g-leech/argmin-gravitas.git',
#       'svn_url': 'https://github.com/g-leech/argmin-gravitas',
#       'homepage': 'https://www.gleech.org',
#       'size': 26612,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Jupyter Notebook',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 4,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/g-leech/argmin-gravitas/pulls/530'},
#      'html': {'href': 'https://github.com/g-leech/argmin-gravitas/pull/530'},
#      'issue': {'href': 'https://api.github.com/repos/g-leech/argmin-gravitas/issues/530'},
#      'comments': {'href': 'https://api.github.com/repos/g-leech/argmin-gravitas/issues/530/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/g-leech/argmin-gravitas/pulls/530/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/g-leech/argmin-gravitas/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/g-leech/argmin-gravitas/pulls/530/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/g-leech/argmin-gravitas/statuses/0d0caa9f7e59b5a891421456ab535a196fcce851'}},
#     'author_association': 'COLLABORATOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 8,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558389',
#   'type': 'PushEvent',
#   'actor': {'id': 34718091,
#    'login': 'ajkr195',
#    'display_login': 'ajkr195',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ajkr195',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34718091?'},
#   'repo': {'id': 223264354,
#    'name': 'ajkr195/SpringbootPureAjax2',
#    'url': 'https://api.github.com/repos/ajkr195/SpringbootPureAjax2'},
#   'payload': {'push_id': 4702131860,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'dc4983e8fb1646856e495629ada59ad7fcacc0b7',
#    'before': '848fe0f12dd9ef2094afc73a65ebd8416c72f986',
#    'commits': [{'sha': 'dc4983e8fb1646856e495629ada59ad7fcacc0b7',
#      'author': {'email': 'ajay@linuxpc', 'name': 'ajay'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ajkr195/SpringbootPureAjax2/commits/dc4983e8fb1646856e495629ada59ad7fcacc0b7'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558380',
#   'type': 'PushEvent',
#   'actor': {'id': 61125289,
#    'login': 'joaofma',
#    'display_login': 'joaofma',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joaofma',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61125289?'},
#   'repo': {'id': 244173588,
#    'name': 'joaofma/datasciencecoursera',
#    'url': 'https://api.github.com/repos/joaofma/datasciencecoursera'},
#   'payload': {'push_id': 4702131853,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0133c71bb670ebfc769dfef0e625ec520d695adf',
#    'before': 'cfe8ed18383973c56840e37044fcf1b60c0683c6',
#    'commits': [{'sha': '0133c71bb670ebfc769dfef0e625ec520d695adf',
#      'author': {'email': '61125289+joaofma@users.noreply.github.com',
#       'name': 'joaofma'},
#      'message': 'Delete datasciencecoursera.Rproj',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/joaofma/datasciencecoursera/commits/0133c71bb670ebfc769dfef0e625ec520d695adf'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558379',
#   'type': 'PushEvent',
#   'actor': {'id': 48918793,
#    'login': 'altair050',
#    'display_login': 'altair050',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/altair050',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48918793?'},
#   'repo': {'id': 244158138,
#    'name': 'altair050/Lab1rs',
#    'url': 'https://api.github.com/repos/altair050/Lab1rs'},
#   'payload': {'push_id': 4702131852,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'efd07c62ad2968524c904d0d2dd7564a8aecd536',
#    'before': '74e6b2da022a39e04473923c4662624a6f549b56',
#    'commits': [{'sha': 'efd07c62ad2968524c904d0d2dd7564a8aecd536',
#      'author': {'email': '48918793+altair050@users.noreply.github.com',
#       'name': 'altair050'},
#      'message': 'Update settings.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/altair050/Lab1rs/commits/efd07c62ad2968524c904d0d2dd7564a8aecd536'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558377',
#   'type': 'PushEvent',
#   'actor': {'id': 56475866,
#    'login': 'marlisa31',
#    'display_login': 'marlisa31',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marlisa31',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56475866?'},
#   'repo': {'id': 242314505,
#    'name': 'marlisa31/arcade-game',
#    'url': 'https://api.github.com/repos/marlisa31/arcade-game'},
#   'payload': {'push_id': 4702131850,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0566cb09d1142b68bfae75e51a2cd826957888e1',
#    'before': 'c0d286daa694f4b8587bc9255541bfa35aa56a3f',
#    'commits': [{'sha': '0566cb09d1142b68bfae75e51a2cd826957888e1',
#      'author': {'email': 'marlisa94@gmx.de', 'name': 'Lisa'},
#      'message': 'Writing README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/marlisa31/arcade-game/commits/0566cb09d1142b68bfae75e51a2cd826957888e1'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:08Z'},
#  {'id': '11647558376',
#   'type': 'CreateEvent',
#   'actor': {'id': 46973960,
#    'login': 'kamil7pl',
#    'display_login': 'kamil7pl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kamil7pl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46973960?'},
#   'repo': {'id': 244177132,
#    'name': 'kamil7pl/losowanie_kluczy_z_tablicy_asocjacyjnej',
#    'url': 'https://api.github.com/repos/kamil7pl/losowanie_kluczy_z_tablicy_asocjacyjnej'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z'},
#  {'id': '11647558373',
#   'type': 'PushEvent',
#   'actor': {'id': 5006555,
#    'login': 'Hadryan',
#    'display_login': 'Hadryan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hadryan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5006555?'},
#   'repo': {'id': 194521665,
#    'name': 'Hadryan/testap',
#    'url': 'https://api.github.com/repos/Hadryan/testap'},
#   'payload': {'push_id': 4702131846,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6770f97055304794d5f967912dd1eb675d3d146e',
#    'before': 'c3359584efab8a0271a69dcca5b3b901e488792d',
#    'commits': [{'sha': '6770f97055304794d5f967912dd1eb675d3d146e',
#      'author': {'email': 'Hadryan@users.noreply.github.com',
#       'name': 'Hadryan'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Hadryan/testap/commits/6770f97055304794d5f967912dd1eb675d3d146e'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z'},
#  {'id': '11647558372',
#   'type': 'PushEvent',
#   'actor': {'id': 49752873,
#    'login': 'clazdo',
#    'display_login': 'clazdo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/clazdo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49752873?'},
#   'repo': {'id': 238330730,
#    'name': 'clazdo/simple-java-maven-app',
#    'url': 'https://api.github.com/repos/clazdo/simple-java-maven-app'},
#   'payload': {'push_id': 4702131847,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1e7b9e179bc6a2226bc8d370c4bfe65b218c5d77',
#    'before': '0d85b7e1fd39bc6978511f92381aa10534ca4c1b',
#    'commits': [{'sha': '1e7b9e179bc6a2226bc8d370c4bfe65b218c5d77',
#      'author': {'email': '49752873+clazdo@users.noreply.github.com',
#       'name': 'clazdo'},
#      'message': 'Update pom.xml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/clazdo/simple-java-maven-app/commits/1e7b9e179bc6a2226bc8d370c4bfe65b218c5d77'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z'},
#  {'id': '11647558370',
#   'type': 'PushEvent',
#   'actor': {'id': 2488011,
#    'login': 'rebeloper',
#    'display_login': 'rebeloper',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rebeloper',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2488011?'},
#   'repo': {'id': 244116030,
#    'name': 'rebeloper/FlashUI',
#    'url': 'https://api.github.com/repos/rebeloper/FlashUI'},
#   'payload': {'push_id': 4702131842,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '98fed920c8d012b7674080dd16fd084c1fb586a2',
#    'before': '3afca74ad0ff89d6e55a51467a312a0347945324',
#    'commits': [{'sha': '98fed920c8d012b7674080dd16fd084c1fb586a2',
#      'author': {'email': 'therebeloper@gmail.com', 'name': 'Alex Nagy'},
#      'message': 'EditableWebImageView',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rebeloper/FlashUI/commits/98fed920c8d012b7674080dd16fd084c1fb586a2'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z'},
#  {'id': '11647558369',
#   'type': 'PushEvent',
#   'actor': {'id': 38477522,
#    'login': 'ltsfran',
#    'display_login': 'ltsfran',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ltsfran',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38477522?'},
#   'repo': {'id': 239794417,
#    'name': 'peru-com/ui',
#    'url': 'https://api.github.com/repos/peru-com/ui'},
#   'payload': {'push_id': 4702131844,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '39bf6610c55a3592148b54fdc5d6d34ef53277f0',
#    'before': '84692a7f6f45258b7cbddfe10a2ea59431b1e67f',
#    'commits': [{'sha': '39bf6610c55a3592148b54fdc5d6d34ef53277f0',
#      'author': {'email': 'luis.tupa@orbis.com.pe', 'name': 'Luis Tupa'},
#      'message': 'feat(components): correct function in Header component',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/peru-com/ui/commits/39bf6610c55a3592148b54fdc5d6d34ef53277f0'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z',
#   'org': {'id': 60931857,
#    'login': 'peru-com',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/peru-com',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60931857?'}},
#  {'id': '11647558365',
#   'type': 'PushEvent',
#   'actor': {'id': 42170829,
#    'login': 'rselebalo',
#    'display_login': 'rselebalo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rselebalo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42170829?'},
#   'repo': {'id': 244173948,
#    'name': 'rselebalo/metric-sum-timer',
#    'url': 'https://api.github.com/repos/rselebalo/metric-sum-timer'},
#   'payload': {'push_id': 4702131841,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f0a067da4cf15df959bd2fae89c2bfb88bd88ae4',
#    'before': '30c86048b93c6d2685a1f9fcde86c40880852880',
#    'commits': [{'sha': 'f0a067da4cf15df959bd2fae89c2bfb88bd88ae4',
#      'author': {'email': '42170829+rselebalo@users.noreply.github.com',
#       'name': 'rselebalo'},
#      'message': 'Update read me',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rselebalo/metric-sum-timer/commits/f0a067da4cf15df959bd2fae89c2bfb88bd88ae4'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z'},
#  {'id': '11647558366',
#   'type': 'IssuesEvent',
#   'actor': {'id': 41597,
#    'login': 'mistic100',
#    'display_login': 'mistic100',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mistic100',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41597?'},
#   'repo': {'id': 33748729,
#    'name': 'mistic100/Photo-Sphere-Viewer',
#    'url': 'https://api.github.com/repos/mistic100/Photo-Sphere-Viewer'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/mistic100/Photo-Sphere-Viewer/issues/344',
#     'repository_url': 'https://api.github.com/repos/mistic100/Photo-Sphere-Viewer',
#     'labels_url': 'https://api.github.com/repos/mistic100/Photo-Sphere-Viewer/issues/344/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/mistic100/Photo-Sphere-Viewer/issues/344/comments',
#     'events_url': 'https://api.github.com/repos/mistic100/Photo-Sphere-Viewer/issues/344/events',
#     'html_url': 'https://github.com/mistic100/Photo-Sphere-Viewer/issues/344',
#     'id': 573566467,
#     'node_id': 'MDU6SXNzdWU1NzM1NjY0Njc=',
#     'number': 344,
#     'title': 'Missing Three.js components: DeviceOrientationControls. Get them from three.js-examples package',
#     'user': {'login': 'lshfong',
#      'id': 35799041,
#      'node_id': 'MDQ6VXNlcjM1Nzk5MDQx',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/35799041?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lshfong',
#      'html_url': 'https://github.com/lshfong',
#      'followers_url': 'https://api.github.com/users/lshfong/followers',
#      'following_url': 'https://api.github.com/users/lshfong/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lshfong/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lshfong/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lshfong/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lshfong/orgs',
#      'repos_url': 'https://api.github.com/users/lshfong/repos',
#      'events_url': 'https://api.github.com/users/lshfong/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lshfong/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2020-03-01T15:33:07Z',
#     'updated_at': '2020-03-01T15:49:07Z',
#     'closed_at': '2020-03-01T15:49:07Z',
#     'author_association': 'NONE',
#     'body': "## Issues guidelines\r\n\r\n- **Indicate your Photo-Sphere-Viewer, ThreeJS and web browser versions**\r\n- Please search in the [documentation](http://photo-sphere-viewer.js.org) before asking.\r\n- Any issue without enough details won't get any answer and will be closed.\r\n- Help requests must be exhaustive, precise and come with some code explaining the need (use Markdown code highlight).\r\n- Bug reports must come with a simple test case, preferably on jsFiddle, Plunker, etc.\r\n"}},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z'},
#  {'id': '11647558362',
#   'type': 'PushEvent',
#   'actor': {'id': 61551630,
#    'login': 'abc1035',
#    'display_login': 'abc1035',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abc1035',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61551630?'},
#   'repo': {'id': 243940616,
#    'name': 'abc1035/easyEnglish',
#    'url': 'https://api.github.com/repos/abc1035/easyEnglish'},
#   'payload': {'push_id': 4702131837,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '078710d03f47e017fa9197b1d8a3982142d458db',
#    'before': 'e0c422c4cbaac51cafe87cd63083de85c7d9cc67',
#    'commits': [{'sha': '078710d03f47e017fa9197b1d8a3982142d458db',
#      'author': {'email': '61551630+abc1035@users.noreply.github.com',
#       'name': 'abc1035'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/abc1035/easyEnglish/commits/078710d03f47e017fa9197b1d8a3982142d458db'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z'},
#  {'id': '11647558356',
#   'type': 'PushEvent',
#   'actor': {'id': 59385139,
#    'login': 'minhyeonlee',
#    'display_login': 'minhyeonlee',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/minhyeonlee',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59385139?'},
#   'repo': {'id': 244176366,
#    'name': 'minhyeonlee/algorithm-python',
#    'url': 'https://api.github.com/repos/minhyeonlee/algorithm-python'},
#   'payload': {'push_id': 4702131833,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '017ffcfa2c7a0501e9b85379b1b05e70b31fbb2a',
#    'before': 'b13a395b24250c8e91e9e7cc64ed34efb9d3af72',
#    'commits': [{'sha': '017ffcfa2c7a0501e9b85379b1b05e70b31fbb2a',
#      'author': {'email': 'minhyeonlee1@gmail.com', 'name': 'Minhyeon Lee'},
#      'message': 'codeUp100 1001-1030',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/minhyeonlee/algorithm-python/commits/017ffcfa2c7a0501e9b85379b1b05e70b31fbb2a'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z'},
#  {'id': '11647558357',
#   'type': 'PushEvent',
#   'actor': {'id': 61322622,
#    'login': 'michaelmizgulin',
#    'display_login': 'michaelmizgulin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/michaelmizgulin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61322622?'},
#   'repo': {'id': 118623628,
#    'name': 'rac-kassel/profs-at-turntables',
#    'url': 'https://api.github.com/repos/rac-kassel/profs-at-turntables'},
#   'payload': {'push_id': 4702131838,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '53dec701ecac44eecc3aaa31e81d29ff6731f842',
#    'before': '7d1a8e8dace593615de045302d5311ed7793292a',
#    'commits': [{'sha': '53dec701ecac44eecc3aaa31e81d29ff6731f842',
#      'author': {'email': '61322622+michaelmizgulin@users.noreply.github.com',
#       'name': 'michaelmizgulin'},
#      'message': 'Update line-up-2020.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rac-kassel/profs-at-turntables/commits/53dec701ecac44eecc3aaa31e81d29ff6731f842'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z',
#   'org': {'id': 35509136,
#    'login': 'rac-kassel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rac-kassel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35509136?'}},
#  {'id': '11647558358',
#   'type': 'DeleteEvent',
#   'actor': {'id': 23270420,
#    'login': 'g-leech',
#    'display_login': 'g-leech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/g-leech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23270420?'},
#   'repo': {'id': 77863671,
#    'name': 'g-leech/argmin-gravitas',
#    'url': 'https://api.github.com/repos/g-leech/argmin-gravitas'},
#   'payload': {'ref': 'staticman_4f4e51d0-69b5-11e8-923b-09e0420093dc',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z'},
#  {'id': '11647558355',
#   'type': 'PushEvent',
#   'actor': {'id': 59843652,
#    'login': 'mezhduprochim',
#    'display_login': 'mezhduprochim',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mezhduprochim',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59843652?'},
#   'repo': {'id': 242702049,
#    'name': 'mezhduprochim/rsschool-cv',
#    'url': 'https://api.github.com/repos/mezhduprochim/rsschool-cv'},
#   'payload': {'push_id': 4702131835,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '04208a19d2122524f529bd130f27aa37ca82ad6a',
#    'before': '6ead5da9b007eb501e45245aedc948abe2a35bbd',
#    'commits': [{'sha': '04208a19d2122524f529bd130f27aa37ca82ad6a',
#      'author': {'email': '59843652+mezhduprochim@users.noreply.github.com',
#       'name': 'mezhduprochim'},
#      'message': 'docs: update cv 3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mezhduprochim/rsschool-cv/commits/04208a19d2122524f529bd130f27aa37ca82ad6a'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z'},
#  {'id': '11647558350',
#   'type': 'PushEvent',
#   'actor': {'id': 39585097,
#    'login': 'ghinawiranti',
#    'display_login': 'ghinawiranti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ghinawiranti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39585097?'},
#   'repo': {'id': 243272231,
#    'name': 'puttri143/ELGG',
#    'url': 'https://api.github.com/repos/puttri143/ELGG'},
#   'payload': {'push_id': 4702131829,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'aa72d066e56fe0d24ff359da90b8dcf70ee36d80',
#    'before': '2eddeeb9866f700fc28b6d6120bb09934c9f975d',
#    'commits': [{'sha': 'aa72d066e56fe0d24ff359da90b8dcf70ee36d80',
#      'author': {'email': 'ghina_wiranti@apps.ipb.ac.id',
#       'name': 'Arih Ghina Wiranti'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/puttri143/ELGG/commits/aa72d066e56fe0d24ff359da90b8dcf70ee36d80'}]},
#   'public': True,
#   'created_at': '2020-03-01T15:49:07Z'}]

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("https://cat-fact.herokuapp.com/facts", params=payload)
json.loads(r.text)
# Out:
# {'all': [{'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 10,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
#    'text': 'Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.',
#    'type': 'cat',
#    'user': {'_id': '5c6fd96df4256a001498a73f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72dbd851021f001415f010',
#    'text': 'The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.',
#    'type': 'cat',
#    'user': {'_id': '5c72dbb751021f001415f00f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'About one in two cats respond to catnip, and only develop a sensitivity to it at around 3 to 6 months of age.',
# ...
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e239999dc76630015d4c5e2',
#    'type': 'cat',
#    'text': 'Cats see only on blue and yellow.',
#    'user': {'_id': '5e239963dc76630015d4c5e1',
#     'name': {'first': 'Eduardo', 'last': 'P. Gomez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e27232ec71d0900152d8518',
#    'type': 'cat',
#    'text': 'Cats are dumb.',
#    'user': {'_id': '5e272323c71d0900152d8517',
#     'name': {'first': 'Andrew', 'last': 'Steele'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f1ade397c00152dd552',
#    'type': 'cat',
#    'text': 'Cat.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f23de397c00152dd553',
#    'type': 'cat',
#    'text': 'Sleep.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3382ccd7ac48001509e153',
#    'type': 'cat',
#    'text': 'Cat is an animal.',
#    'user': {'_id': '5e3381f3d7ac48001509e151',
#     'name': {'first': 'Dicka', 'last': 'Ismaji'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e344e7acd8efb0015ae3055',
#    'type': 'cat',
#    'text': 'Cat live, on average, for about 7-8 years.',
#    'user': {'_id': '5e344e3ccd8efb0015ae3054',
#     'name': {'first': 'RYAN', 'last': 'STULTZ'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3534d8cd8efb0015ae305c',
#    'type': 'cat',
#    'text': 'Hi.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e35436d11559000151bf453',
#    'type': 'cat',
#    'text': '123.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e355bf411559000151bf454',
#    'type': 'cat',
#    'text': 'Fgf.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e380ea32035630015618254',
#    'type': 'cat',
#    'text': 'Asd.',
#    'user': {'_id': '5e380e9b2035630015618253',
#     'name': {'first': 'dm', 'last': 'max'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e56fdf375991a0015429ffc',
#    'type': 'cat',
#    'text': 'Bbb.',
#    'user': {'_id': '5e56fddd75991a0015429ffb',
#     'name': {'first': 'Cristian', 'last': 'Salcedo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e353507cd8efb0015ae305d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e4c4e10a38ae60015b04a7e',
#    'type': 'cat',
#    'text': "Cats think humans have night vision too, so when we step on their tail in the middle of the night, they think it's on purpose.",
#    'user': {'_id': '5e4c4dc5a38ae60015b04a7d',
#     'name': {'first': 'Nathaniel J', 'last': 'McDermott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e546a054e83e80015a0e320',
#    'type': 'cat',
#    'text': "Contrary to popular belief, some cats actually don't mind water. The hairless Sphynx cat enjoys it, especially if it is warm.",
#    'user': {'_id': '5e54675a4e83e80015a0e313',
#     'name': {'first': "L'hibou", 'last': 'Ambigu'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
r = requests.post('https://cat-fact.herokuapp.com/facts', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'message': 'Sign in first'}
